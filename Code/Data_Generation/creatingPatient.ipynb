# %%
import matplotlib
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
cols = ['ID', 'Diagnosis', 'radius', 'texture', 'perimeter', 'area', 'smoothness', 'compactness', 'concavity', 'concave_points', 'symmetry', 'fractal_dimension',
        'radius_SE', 'texture_SE', 'perimeter_SE', 'area_SE', 'smoothness_SE', 'compactness_SE', 'concavity_SE', 'concave_points_SE', 'symmetry_SE', 'fractal_dimension_SE',
        'radius_MAX', 'texture_MAX', 'perimeter_MAX', 'area_MAX', 'smoothness_MAX', 'compactness_MAX', 'concavity_MAX', 'concave_points_MAX', 'symmetry_MAX', 'fractal_dimension_MAX']
df = pd.read_csv('../../Wisconsin_Database/wdbc.data', header=None)
df.columns = cols
df['Diagnosis'] = df['Diagnosis'].map(
                   {'M':1 ,'B':0})
print(df.shape)
# Out:
# (569, 32)

# %%
arr2D = df.to_numpy()
columnIndex = 1
sortedArr = arr2D[arr2D[:,columnIndex].argsort()]
numZeros = list(sortedArr[:, 1]).count(0)
benignDF, malignantDF = pd.DataFrame(sortedArr[0:numZeros]), pd.DataFrame(sortedArr[numZeros:])
benignDF.columns = cols
malignantDF.columns = cols

# %%
from turtle import width


def generateNewFeatureVal(df, col, numberOfBins):
    print('Column: {}'.format(col))
    print('\tMin: {}, Max: {}, Mean: {:.02f}, Std Dev: {:.02f}'.format(min(df[col]), max(df[col]), sum(df[col])/len(df[col]), np.std(df[col])))
    hist, bins = np.histogram(df[col], bins=numberOfBins)
    print('New Graph')

    bin_midpoints = bins[:-1] + np.diff(bins)/2
    cdf = np.cumsum(hist)
    cdf = cdf / cdf[-1]
    values = np.random.rand(1)
    value_bins = np.searchsorted(cdf, values)
    random_from_cdf = bin_midpoints[value_bins]
    plt.hist(df[col], bins = bins)
    plt.axvline(random_from_cdf, color='orange', linewidth='5')
    plt.show()

print(benignDF.columns)
patientVal = []
for i in benignDF.columns[1:]:
    generateNewFeatureVal(benignDF, i, 25)
# Out:
# Index(['ID', 'Diagnosis', 'radius', 'texture', 'perimeter', 'area',
#        'smoothness', 'compactness', 'concavity', 'concave_points', 'symmetry',
#        'fractal_dimension', 'radius_SE', 'texture_SE', 'perimeter_SE',
#        'area_SE', 'smoothness_SE', 'compactness_SE', 'concavity_SE',
#        'concave_points_SE', 'symmetry_SE', 'fractal_dimension_SE',
#        'radius_MAX', 'texture_MAX', 'perimeter_MAX', 'area_MAX',
#        'smoothness_MAX', 'compactness_MAX', 'concavity_MAX',
#        'concave_points_MAX', 'symmetry_MAX', 'fractal_dimension_MAX'],
#       dtype='object')
# Column: Diagnosis
# 	Min: 0.0, Max: 0.0, Mean: 0.00, Std Dev: 0.00
# New Graph
# Column: radius
# 	Min: 6.981, Max: 17.85, Mean: 12.15, Std Dev: 1.78
# New Graph
# Column: texture
# 	Min: 9.71, Max: 33.81, Mean: 17.91, Std Dev: 3.99
# New Graph
# Column: perimeter
# 	Min: 43.79, Max: 114.6, Mean: 78.08, Std Dev: 11.79
# New Graph
# Column: area
# 	Min: 143.5, Max: 992.1, Mean: 462.79, Std Dev: 134.10
# New Graph
# Column: smoothness
# 	Min: 0.05263, Max: 0.1634, Mean: 0.09, Std Dev: 0.01
# New Graph
# Column: compactness
# 	Min: 0.01938, Max: 0.2239, Mean: 0.08, Std Dev: 0.03
# New Graph
# Column: concavity
# 	Min: 0.0, Max: 0.4108, Mean: 0.05, Std Dev: 0.04
# New Graph
# Column: concave_points
# 	Min: 0.0, Max: 0.08534, Mean: 0.03, Std Dev: 0.02
# New Graph
# Column: symmetry
# 	Min: 0.106, Max: 0.2743, Mean: 0.17, Std Dev: 0.02
# New Graph
# Column: fractal_dimension
# 	Min: 0.05185, Max: 0.09575, Mean: 0.06, Std Dev: 0.01
# New Graph
# Column: radius_SE
# 	Min: 0.1115, Max: 0.8811, Mean: 0.28, Std Dev: 0.11
# New Graph
# Column: texture_SE
# 	Min: 0.3602, Max: 4.885, Mean: 1.22, Std Dev: 0.59
# New Graph
# Column: perimeter_SE
# 	Min: 0.757, Max: 5.118, Mean: 2.00, Std Dev: 0.77
# New Graph
# Column: area_SE
# 	Min: 6.802, Max: 77.11, Mean: 21.14, Std Dev: 8.83
# New Graph
# Column: smoothness_SE
# 	Min: 0.001713, Max: 0.02177, Mean: 0.01, Std Dev: 0.00
# New Graph
# Column: compactness_SE
# 	Min: 0.002252, Max: 0.1064, Mean: 0.02, Std Dev: 0.02
# New Graph
# Column: concavity_SE
# 	Min: 0.0, Max: 0.396, Mean: 0.03, Std Dev: 0.03
# New Graph
# Column: concave_points_SE
# 	Min: 0.0, Max: 0.05279, Mean: 0.01, Std Dev: 0.01
# New Graph
# Column: symmetry_SE
# 	Min: 0.009539, Max: 0.06146, Mean: 0.02, Std Dev: 0.01
# New Graph
# Column: fractal_dimension_SE
# 	Min: 0.0008948, Max: 0.02984, Mean: 0.00, Std Dev: 0.00
# New Graph
# Column: radius_MAX
# 	Min: 7.93, Max: 19.82, Mean: 13.38, Std Dev: 1.98
# New Graph
# Column: texture_MAX
# 	Min: 12.02, Max: 41.78, Mean: 23.52, Std Dev: 5.49
# New Graph
# Column: perimeter_MAX
# 	Min: 50.41, Max: 127.1, Mean: 87.01, Std Dev: 13.51
# New Graph
# Column: area_MAX
# 	Min: 185.2, Max: 1210.0, Mean: 558.90, Std Dev: 163.37
# New Graph
# Column: smoothness_MAX
# 	Min: 0.07117, Max: 0.2006, Mean: 0.12, Std Dev: 0.02
# New Graph
# Column: compactness_MAX
# 	Min: 0.02729, Max: 0.5849, Mean: 0.18, Std Dev: 0.09
# New Graph
# Column: concavity_MAX
# 	Min: 0.0, Max: 1.252, Mean: 0.17, Std Dev: 0.14
# New Graph
# Column: concave_points_MAX
# 	Min: 0.0, Max: 0.175, Mean: 0.07, Std Dev: 0.04
# New Graph
# Column: symmetry_MAX
# 	Min: 0.1566, Max: 0.4228, Mean: 0.27, Std Dev: 0.04
# New Graph
# Column: fractal_dimension_MAX
# 	Min: 0.05521, Max: 0.1486, Mean: 0.08, Std Dev: 0.01
# New Graph
